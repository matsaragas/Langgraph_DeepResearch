# %%
from agent import graph

#state = graph.invoke({"messages": [{"role": "user", "content": "Who won the euro 2024"}], "max_research_loops": 3, "initial_search_query_count": 3})
from IPython.display import Image, display

display(Image(graph.get_graph(xray=True).draw_mermaid_png()))

# %%
img = Image(graph.get_graph(xray=True).draw_mermaid_png(), width=200, height=500)

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 img.save("search_graph.png")
#
# AttributeError: 'Image' object has no attribute 'save'
